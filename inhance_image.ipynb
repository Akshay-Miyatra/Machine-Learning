# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('car.jpg');
img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

#kernal
k1 = np.array([[-1,-1,-1],[-1,10,-1],[-1,-1,-1]])
k2= np.array([[-0,-1,0],[-1,5,-1],[0,-1,0]])
b3 = np.array([[0, -1, 0],
                        [-1, 6, -1],
                        [0, -1, 0]])


#apply
img1=cv2.filter2D(img,-1,k1)

plt.figure(figsize=(10,6))
plt.subplot(3,2,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(3,2,2),plt.imshow(img1),plt.title('k1'),plt.axis('off')
plt.subplot(3,2,3),plt.imshow(img1),plt.title('k2'),plt.axis('off')
plt.subplot(3,2,4),plt.imshow(img1),plt.title('k2'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'k2'}>,
# ...
#  Text(0.5, 1.0, 'k2'),
#  (-0.5, 285.5, 175.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('car.jpg');
img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

gauss = cv2.GaussianBlur(img,(5,5),0)
s_image = cv2.addWeighted(img,1.5,gauss,-0.4,0)

plt.subplot(1,2,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(s_image),plt.title('s_image'),plt.axis('off')
# Out:
# (<Axes: title={'center': 's_image'}>,
# ...
#  Text(0.5, 1.0, 's_image'),
#  (-0.5, 285.5, 175.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('a.jpg');
img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

k1=np.array([[0,-1,-1],[1,0,1],[1,1,0]])

img1 = cv2.filter2D(img,-1,k1)


plt.subplot(2,3,1),plt.imshow(img),plt.title('source image'),plt.axis('off')
plt.subplot(2,3,2),plt.imshow(img1,cmap='gray'),plt.title(''),plt.axis('off')
# Out:
# (<Axes: >,
# ...
#  Text(0.5, 1.0, ''),
#  (-0.5, 735.5, 735.5, -0.5))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Read and convert image to RGB
img = cv2.imread('tiger1.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Apply Gaussian blur to reduce noise
blur = cv2.GaussianBlur(img_rgb, (5, 5), 0)

# Convert blurred image to grayscale for edge detection
gray = cv2.cvtColor(blur, cv2.COLOR_RGB2GRAY)

# Apply Laplacian edge detection
laplacian = cv2.Laplacian(gray, cv2.CV_64F)
laplacian = cv2.convertScaleAbs(laplacian)  # convert back to uint8

# Plotting
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.imshow(img_rgb)
plt.title('Source Image')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(blur)
plt.title('Gaussian Blur')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian Edge Detection')
plt.axis('off')

plt.show()
